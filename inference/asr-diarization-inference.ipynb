# %%
# !git clone https://github.com/AbdelrhmanElnenaey/ASR_for_egyptian_dialect
# %cd ASR_for_egyptian_dialect
# Out:
# Cloning into 'ASR_for_egyptian_dialect'...
# remote: Enumerating objects: 493, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 493 (delta 50), reused 28 (delta 14), pack-reused 406
# Receiving objects: 100% (493/493), 31.66 MiB | 1.13 MiB/s, done.
# Resolving deltas: 100% (259/259), done.
# /kaggle/working/ASR_for_egyptian_dialect

# %%
# !apt-get install -y sox libsndfile1 ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-7ubuntu0.2).
# libsndfile1 set to manually installed.
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 80 not upgraded.
# Need to get 807 kB of archives.
# After this operation, 7653 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libmagic-mgc amd64 1:5.38-4 [218 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libmagic1 amd64 1:5.38-4 [75.9 kB]
# ...

# %%
# !pip install wget
# !pip install text-unidecode
# !pip install torchaudio -f https://download.pytorch.org/whl/torch_stable.html
# !pip install gdown
# !pip install demucs
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=fb86fdcd6d551df467a597b3821dc18fc2fffca2c2532529780deb80c391abf0
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.7 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 6.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
BRANCH='main'
# !pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[asr]
# Out:
# DEPRECATION: git+https://github.com/NVIDIA/NeMo.git@main#egg=nemo_toolkit[asr] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# ...
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-nwlwt5s4/nemo-toolkit_313ab41f307b4e80b3e883829417ad39
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git /tmp/pip-install-nwlwt5s4/nemo-toolkit_313ab41f307b4e80b3e883829417ad39
#   Resolved https://github.com/NVIDIA/NeMo.git to commit cd0d2c277fb865e658384d2948eb96d3c313db5a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 3.5 MB/s eta 0:00:00
# ...

# %%
# !python /kaggle/input/scriptss/modify_diarizer.py
# Out:
# Modified function in /opt/conda/lib/python3.10/site-packages/nemo/collections/asr/models/clustering_diarizer.py.

# %%
import os
os._exit(00)

# %%
# !python /kaggle/input/generate-manifest/generate_manifest.py \
    --paths2audio_files audio_files.txt \
    --data_dir /kaggle/input/diarization/wavs \
    --manifest_filepath test_manifest.json \
    --add_duration

# %%
# !python /kaggle/input/inference2/Inference.py\
--asr_model /kaggle/input/asr-model-ckpt/asr_model.ckpt \
--data_dir /kaggle/input/diarization/wavs \
--asr_output results.csv \
--input_manifest_path test_manifest.json \
--output_manifest_path test_manifest_vocals.json \
--temp_output_dir temp_outputs \
--mono_output_dir temp_outputs_mono \
--config_path /kaggle/working/ASR_for_egyptian_dialect/configs/FC-transducer-inference.yaml
# Out:
# Using device: cuda
# [NeMo I 2024-07-24 19:31:44 mixins:173] Tokenizer SentencePieceTokenizer initialized with 256 tokens
# [NeMo W 2024-07-24 19:31:45 audio_to_text_dataset:830] Could not load dataset as `manifest_filepath` was None. Provided config : {'manifest_filepath': None, 'sample_rate': 16000, 'batch_size': 32, 'shuffle': True, 'num_workers': 8, 'pin_memory': True, 'max_duration': 16.7, 'min_duration': 0.1, 'is_tarred': False, 'tarred_audio_filepaths': None, 'shuffle_n': 2048, 'bucketing_strategy': 'fully_randomized', 'bucketing_batch_size': None}
# [NeMo W 2024-07-24 19:31:45 audio_to_text_dataset:830] Could not load dataset as `manifest_filepath` was None. Provided config : {'manifest_filepath': None, 'sample_rate': 16000, 'batch_size': 32, 'shuffle': False, 'use_start_end_token': False, 'num_workers': 8, 'pin_memory': True}
# [NeMo I 2024-07-24 19:31:45 features:305] PADDING: 0
# ...
