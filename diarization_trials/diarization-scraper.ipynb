# %%
# !pip install yt-dlp pydub youtube-transcript-api

# %%
import yt_dlp
from pydub import AudioSegment
from youtube_transcript_api import YouTubeTranscriptApi
import json
import os

def download_audio(video_url, output_path):
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': output_path
    }
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])

def get_transcript(video_id):
    transcript = YouTubeTranscriptApi.get_transcript(video_id)
    return transcript

def split_durations(txt, name, duration):
    length = len(txt) - len(name) - 1
    idx = txt.index(name)
    duration1 = duration * idx/length
    duration2 = duration - duration1
    return duration1, duration2

def convert_transcript_to_json(transcript, name):
    transcript_json = []
    last_speaker = name if transcript[0]["text"].find(name) != -1 else "Tim Ferriss:"
    last_text = ""
    last_start = 0
    last_duration = 0
    for entry in transcript:
        txt = entry["text"].replace("\u00a0", "").replace("\n", " ")
        if not name in txt and not "Tim Ferriss:" in txt:
            last_text += " " + txt
            last_duration += entry["duration"]
        elif name in txt and "Tim Ferriss:" in txt:
            first_name = txt.split(":")[0]
            other_name = "Tim Ferriss" if first_name == name.split(":")[0] else name
            first_name_idx = txt.index(first_name)
            other_name_idx = txt.index(other_name)
            assert(first_name_idx == 0)
            
            duration1, duration2 = split_durations(txt, other_name, entry["duration"])
            
            transcript_json.append({
                "speaker": last_speaker.split(":")[0],
                "start_time": last_start,
                "end_time": last_start + last_duration,
                "text": last_text
            })

            transcript_json.append({
                "speaker": first_name,
                "start_time": last_start + last_duration,
                "end_time": last_start + last_duration + duration1,
                "text": txt[first_name_idx + len(first_name) + 2: other_name_idx - 1]
            })
            
            last_speaker = other_name
            last_start = last_start + last_duration + duration1
            last_duration = duration2
            last_text = txt[other_name_idx + len(other_name) + 1:]
        else:
            found_name = name if txt.find(name) != -1 else "Tim Ferriss:"

            duration1, duration2 = split_durations(txt, found_name, entry["duration"])
            last_duration += duration1
            transcript_json.append({
                "speaker": last_speaker.split(":")[0],
                "start_time": last_start,
                "end_time": last_start + last_duration,
                "text": last_text
            })
            
            last_speaker = found_name
            last_start = last_start + last_duration
            last_duration = duration2
            last_text = txt[txt.index(found_name) + len(found_name) + 1:]
            
    transcript_json.append({
        "speaker": last_speaker.split(":")[0],
        "start_time": last_start,
        "end_time": last_start + last_duration,
        "text": last_text
    })
    return transcript_json

def save_json(data, output_file):
    with open(output_file, 'w') as f:
        json.dump(data, f, indent=4)

def main(name, video_url):
    video_id = video_url.split("v=")[1]

    output_path = f"audio/{video_id}.wav"
    download_audio(video_url, output_path)
    transcript = get_transcript(video_id)
    transcript_json = convert_transcript_to_json(transcript, name)

    output_file = f"transcripts/{video_id}.json"
    save_json(transcript_json, output_file)
    print(f"Transcript saved to {output_file}")

# %%
video_urls = {
    "Soman Chainani:": "https://www.youtube.com/watch?v=B2r3A2AIm_Y",
    "Claire Hughes Johnson:": "https://www.youtube.com/watch?v=ZHCtb80SUHQ",
    "Dr. David Spiegel:": "https://www.youtube.com/watch?v=wk89rJpaj6w",
    "Martha Beck:": "https://www.youtube.com/watch?v=Ieu68CfTR4g",
    "Craig Foster:": "https://www.youtube.com/watch?v=_tBrxckIwJw",
    "Matt Pottinger:": "https://www.youtube.com/watch?v=hOMpnA-iMRg",
    "Noah Kagan:": "https://www.youtube.com/watch?v=_htIvi4JzOs",
    "Chris Beresford-Hill:": "https://www.youtube.com/watch?v=lwZuRbGvKYs",
    "Dr. Nolan Williams:": "https://www.youtube.com/watch?v=UO7IgQ_x-Qg",
    "Matt Mullenweg:": "https://www.youtube.com/watch?v=pWpaCLIUnXo",
    "Kevin Rose:": "https://www.youtube.com/watch?v=bYXa5RCGLiM",
    "Andrew Rosener:": "https://www.youtube.com/watch?v=ApCGeST90RA",
    "Willoughby Britton:": "https://www.youtube.com/watch?v=WdmvoX1RZWA",
    "Sheila Heen:": "https://www.youtube.com/watch?v=r6ZxOK2Ub-0",
    "Morgan Housel:": "https://www.youtube.com/watch?v=InQb76J9-HY",
    "Apollo Robbins:": "https://www.youtube.com/watch?v=2Qiv7oCVq5E",
    "Rich Paul:": "https://www.youtube.com/watch?v=t1yWC-HufEA",
    "Arnold Schwarzenegger:": "https://www.youtube.com/watch?v=uoabKgDX9GE",
    "Shane Parrish:": "https://www.youtube.com/watch?v=-T30rY6Nqrc",
    "Sam Corcos:": "https://www.youtube.com/watch?v=MtrkDoQFArU",
    "Arthur Brooks:": "https://www.youtube.com/watch?v=LFKY1scJepM",
    "Kevin Rose:": "https://www.youtube.com/watch?v=_fklX2OonR0",
    "Daniil Liberman:": "https://www.youtube.com/watch?v=5zP75PCZ_P0",
    "Justin Gary:": "https://www.youtube.com/watch?v=vf6TYIHwB50",
    "Dr. Shirley Sahrmann:": "https://www.youtube.com/watch?v=KPhd-Qua72E"
}

# %%
# !kaggle d version -p "/kaggle/working" --dir-mode zip -m "YT"

# %%
for name, url in video_urls.items():
    main(name, url)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=B2r3A2AIm_Y
# [youtube] B2r3A2AIm_Y: Downloading webpage
# WARNING: [youtube] Webpage contains broken formats (poToken experiment detected). Ignoring initial player response
# [youtube] B2r3A2AIm_Y: Downloading ios player API JSON
# [youtube] B2r3A2AIm_Y: Downloading player d60b0ef9
# [youtube] B2r3A2AIm_Y: Downloading web player API JSON
# WARNING: [youtube] API returned broken formats (poToken experiment detected). Retrying (1/3)...
# [youtube] B2r3A2AIm_Y: Downloading web player API JSON
# [youtube] B2r3A2AIm_Y: Downloading m3u8 information
# [info] B2r3A2AIm_Y: Downloading 1 format(s): 251
# [download] audio/B2r3A2AIm_Y.wav has already been downloaded
# [download] 100% of   92.54MiB
# Transcript saved to transcripts/B2r3A2AIm_Y.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZHCtb80SUHQ
# [youtube] ZHCtb80SUHQ: Downloading webpage
# [youtube] ZHCtb80SUHQ: Downloading ios player API JSON
# [youtube] ZHCtb80SUHQ: Downloading m3u8 information
# [info] ZHCtb80SUHQ: Downloading 1 format(s): 251
# [download] audio/ZHCtb80SUHQ.wav has already been downloaded
# [download] 100% of  110.05MiB
# Transcript saved to transcripts/ZHCtb80SUHQ.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wk89rJpaj6w
# [youtube] wk89rJpaj6w: Downloading webpage
# [youtube] wk89rJpaj6w: Downloading ios player API JSON
# [youtube] wk89rJpaj6w: Downloading m3u8 information
# [info] wk89rJpaj6w: Downloading 1 format(s): 251
# [download] audio/wk89rJpaj6w.wav has already been downloaded
# [download] 100% of   75.68MiB
# Transcript saved to transcripts/wk89rJpaj6w.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ieu68CfTR4g
# [youtube] Ieu68CfTR4g: Downloading webpage
# [youtube] Ieu68CfTR4g: Downloading ios player API JSON
# [youtube] Ieu68CfTR4g: Downloading m3u8 information
# [info] Ieu68CfTR4g: Downloading 1 format(s): 251
# [download] audio/Ieu68CfTR4g.wav has already been downloaded
# [download] 100% of  113.38MiB
# Transcript saved to transcripts/Ieu68CfTR4g.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_tBrxckIwJw
# [youtube] _tBrxckIwJw: Downloading webpage
# [youtube] _tBrxckIwJw: Downloading ios player API JSON
# [youtube] _tBrxckIwJw: Downloading m3u8 information
# [info] _tBrxckIwJw: Downloading 1 format(s): 251
# [download] audio/_tBrxckIwJw.wav has already been downloaded
# [download] 100% of   92.91MiB
# Transcript saved to transcripts/_tBrxckIwJw.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hOMpnA-iMRg
# [youtube] hOMpnA-iMRg: Downloading webpage
# [youtube] hOMpnA-iMRg: Downloading ios player API JSON
# [youtube] hOMpnA-iMRg: Downloading m3u8 information
# [info] hOMpnA-iMRg: Downloading 1 format(s): 251
# [download] audio/hOMpnA-iMRg.wav has already been downloaded
# [download] 100% of   87.50MiB
# Transcript saved to transcripts/hOMpnA-iMRg.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_htIvi4JzOs
# [youtube] _htIvi4JzOs: Downloading webpage
# [youtube] _htIvi4JzOs: Downloading ios player API JSON
# [youtube] _htIvi4JzOs: Downloading m3u8 information
# [info] _htIvi4JzOs: Downloading 1 format(s): 251
# [download] audio/_htIvi4JzOs.wav has already been downloaded
# [download] 100% of  196.69MiB
# Transcript saved to transcripts/_htIvi4JzOs.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lwZuRbGvKYs
# [youtube] lwZuRbGvKYs: Downloading webpage
# [youtube] lwZuRbGvKYs: Downloading ios player API JSON
# [youtube] lwZuRbGvKYs: Downloading m3u8 information
# [info] lwZuRbGvKYs: Downloading 1 format(s): 251
# [download] audio/lwZuRbGvKYs.wav has already been downloaded
# [download] 100% of  118.81MiB
# Transcript saved to transcripts/lwZuRbGvKYs.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UO7IgQ_x-Qg
# [youtube] UO7IgQ_x-Qg: Downloading webpage
# [youtube] UO7IgQ_x-Qg: Downloading ios player API JSON
# [youtube] UO7IgQ_x-Qg: Downloading m3u8 information
# [info] UO7IgQ_x-Qg: Downloading 1 format(s): 251
# [download] audio/UO7IgQ_x-Qg.wav has already been downloaded
# [download] 100% of  128.59MiB
# Transcript saved to transcripts/UO7IgQ_x-Qg.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pWpaCLIUnXo
# [youtube] pWpaCLIUnXo: Downloading webpage
# [youtube] pWpaCLIUnXo: Downloading ios player API JSON
# [youtube] pWpaCLIUnXo: Downloading m3u8 information
# [info] pWpaCLIUnXo: Downloading 1 format(s): 251
# [download] audio/pWpaCLIUnXo.wav has already been downloaded
# [download] 100% of  129.72MiB
# Transcript saved to transcripts/pWpaCLIUnXo.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_fklX2OonR0
# [youtube] _fklX2OonR0: Downloading webpage
# [youtube] _fklX2OonR0: Downloading ios player API JSON
# [youtube] _fklX2OonR0: Downloading m3u8 information
# [info] _fklX2OonR0: Downloading 1 format(s): 251
# [download] audio/_fklX2OonR0.wav has already been downloaded
# [download] 100% of  105.36MiB
# Transcript saved to transcripts/_fklX2OonR0.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ApCGeST90RA
# [youtube] ApCGeST90RA: Downloading webpage
# [youtube] ApCGeST90RA: Downloading ios player API JSON
# [youtube] ApCGeST90RA: Downloading m3u8 information
# [info] ApCGeST90RA: Downloading 1 format(s): 251
# [download] audio/ApCGeST90RA.wav has already been downloaded
# [download] 100% of  126.23MiB
# Transcript saved to transcripts/ApCGeST90RA.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WdmvoX1RZWA
# [youtube] WdmvoX1RZWA: Downloading webpage
# [youtube] WdmvoX1RZWA: Downloading ios player API JSON
# [youtube] WdmvoX1RZWA: Downloading m3u8 information
# [info] WdmvoX1RZWA: Downloading 1 format(s): 251
# [download] audio/WdmvoX1RZWA.wav has already been downloaded
# [download] 100% of   99.45MiB
# Transcript saved to transcripts/WdmvoX1RZWA.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=r6ZxOK2Ub-0
# [youtube] r6ZxOK2Ub-0: Downloading webpage
# [youtube] r6ZxOK2Ub-0: Downloading ios player API JSON
# [youtube] r6ZxOK2Ub-0: Downloading m3u8 information
# [info] r6ZxOK2Ub-0: Downloading 1 format(s): 251
# [download] audio/r6ZxOK2Ub-0.wav has already been downloaded
# [download] 100% of   98.02MiB
# Transcript saved to transcripts/r6ZxOK2Ub-0.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=InQb76J9-HY
# [youtube] InQb76J9-HY: Downloading webpage
# [youtube] InQb76J9-HY: Downloading ios player API JSON
# [youtube] InQb76J9-HY: Downloading m3u8 information
# [info] InQb76J9-HY: Downloading 1 format(s): 251
# [download] audio/InQb76J9-HY.wav has already been downloaded
# [download] 100% of  106.29MiB
# Transcript saved to transcripts/InQb76J9-HY.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2Qiv7oCVq5E
# [youtube] 2Qiv7oCVq5E: Downloading webpage
# [youtube] 2Qiv7oCVq5E: Downloading ios player API JSON
# [youtube] 2Qiv7oCVq5E: Downloading m3u8 information
# [info] 2Qiv7oCVq5E: Downloading 1 format(s): 251
# [download] audio/2Qiv7oCVq5E.wav has already been downloaded
# [download] 100% of  121.60MiB
# Transcript saved to transcripts/2Qiv7oCVq5E.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=t1yWC-HufEA
# [youtube] t1yWC-HufEA: Downloading webpage
# [youtube] t1yWC-HufEA: Downloading ios player API JSON
# [youtube] t1yWC-HufEA: Downloading m3u8 information
# [info] t1yWC-HufEA: Downloading 1 format(s): 251
# [download] audio/t1yWC-HufEA.wav has already been downloaded
# [download] 100% of   45.32MiB
# Transcript saved to transcripts/t1yWC-HufEA.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uoabKgDX9GE
# [youtube] uoabKgDX9GE: Downloading webpage
# [youtube] uoabKgDX9GE: Downloading ios player API JSON
# [youtube] uoabKgDX9GE: Downloading m3u8 information
# [info] uoabKgDX9GE: Downloading 1 format(s): 251
# [download] audio/uoabKgDX9GE.wav has already been downloaded
# [download] 100% of   61.06MiB
# Transcript saved to transcripts/uoabKgDX9GE.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-T30rY6Nqrc
# [youtube] -T30rY6Nqrc: Downloading webpage
# [youtube] -T30rY6Nqrc: Downloading ios player API JSON
# [youtube] -T30rY6Nqrc: Downloading m3u8 information
# [info] -T30rY6Nqrc: Downloading 1 format(s): 251
# [download] audio/-T30rY6Nqrc.wav has already been downloaded
# [download] 100% of   96.28MiB
# Transcript saved to transcripts/-T30rY6Nqrc.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MtrkDoQFArU
# [youtube] MtrkDoQFArU: Downloading webpage
# [youtube] MtrkDoQFArU: Downloading ios player API JSON
# [youtube] MtrkDoQFArU: Downloading m3u8 information
# [info] MtrkDoQFArU: Downloading 1 format(s): 251
# [download] audio/MtrkDoQFArU.wav has already been downloaded
# [download] 100% of  147.05MiB
# Transcript saved to transcripts/MtrkDoQFArU.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LFKY1scJepM
# [youtube] LFKY1scJepM: Downloading webpage
# [youtube] LFKY1scJepM: Downloading ios player API JSON
# [youtube] LFKY1scJepM: Downloading m3u8 information
# [info] LFKY1scJepM: Downloading 1 format(s): 251
# [download] audio/LFKY1scJepM.wav has already been downloaded
# [download] 100% of  132.49MiB
# Transcript saved to transcripts/LFKY1scJepM.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5zP75PCZ_P0
# [youtube] 5zP75PCZ_P0: Downloading webpage
# [youtube] 5zP75PCZ_P0: Downloading ios player API JSON
# [youtube] 5zP75PCZ_P0: Downloading m3u8 information
# [info] 5zP75PCZ_P0: Downloading 1 format(s): 251
# [download] audio/5zP75PCZ_P0.wav has already been downloaded
# [download] 100% of  132.83MiB
# Transcript saved to transcripts/5zP75PCZ_P0.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vf6TYIHwB50
# [youtube] vf6TYIHwB50: Downloading webpage
# [youtube] vf6TYIHwB50: Downloading ios player API JSON
# [youtube] vf6TYIHwB50: Downloading m3u8 information
# [info] vf6TYIHwB50: Downloading 1 format(s): 251
# [download] audio/vf6TYIHwB50.wav has already been downloaded
# [download] 100% of  112.93MiB
# Transcript saved to transcripts/vf6TYIHwB50.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KPhd-Qua72E
# [youtube] KPhd-Qua72E: Downloading webpage
# [youtube] KPhd-Qua72E: Downloading ios player API JSON
# [youtube] KPhd-Qua72E: Downloading m3u8 information
# [info] KPhd-Qua72E: Downloading 1 format(s): 251
# [download] audio/KPhd-Qua72E.wav has already been downloaded
# [download] 100% of   82.58MiB
# Transcript saved to transcripts/KPhd-Qua72E.json
